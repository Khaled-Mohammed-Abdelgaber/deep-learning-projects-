# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaled-Mohammed-Abdelgaber/deep-learning-projects-/blob/main/NLP/text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Reweighting a probability distribution to a different temperature

# %%
import numpy as np 
def reweight_distribution(original_distribution, temperature=0.5):
  """
  original_distribution is 1D numpy array 

  first thing we return the weight to its original without exponential 
  then divide it by tempreture 
  then take exponential
  then calculate new distribution 
  input is e^y
  output is [e^(y/t)] / [sum(e^(y/t))]
  where t is tempreture
  by doing that we change distribution of weights
  note that:
    Higher temperatures result in sampling distributions of higher entropy that will generate more surprising and unstructured generated data,
   whereas a lower temperature will result in less randomness and much more predictable generated data 
  """
  distribution = np.log(original_distribution) / temperature
  distribution = np.exp(distribution)
  return distribution / np.sum(distribution)

# %% [markdown]
# ##Downloading and parsing the initial text file

# %%
import tensorflow as tf
#path = tf.keras.utils.get_file(fname = ... , origin = url_link to datasets)
path = tf.keras.utils.get_file( 'nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt') #to download datasets
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 614400/600901 [==============================] - 1s 2us/step

# %%
text = open(path).read().lower() #to read datasets and make it lowercase

# %%
print('Corpus length:', len(text))#will print the number of character in this text
# Out:
# Corpus length: 600893

# %% [markdown]
# ##Vectorizing sequences of characters

# %% [markdown]
# passing string to set will return all character of that string and repeated will be appear once.
# ```
# set("Khaled Mohammed AbdelGaber")
# output:
#       {' ', 'A', 'G', 'K', 'M', 'a', 'b', 'd', 'e', 'h', 'l', 'm', 'o', 'r'}
# ```
# sorted() function used to sort all things characters or numbers it return a list of sorted elements
# ```
# sorted(set("Khaled Mohammed AbdelGaber"))
# output:
#       [' ', 'A', 'G', 'K', 'M', 'a', 'b', 'd', 'e', 'h', 'l', 'm', 'o', 'r']
# ```
# what we will do is vectorization by:
# * storing all unique character in a list in variable called **chars**.
# * then store this characters in dictionary called **char_indices** its key is character itself and value is character index in **chars** list.
# *  **last step is to make two numpy arrays input of model and output:**
#   * input is a sentence of 60 characters and output is single character (will be the next one of scentence).
#
#  * but model does not understand alphabetic character so we will replace sentence with vector of 60 element. its elements values is 0 or 1.
#
#   * 1 in element with index related to character that found in sentence
#   * output will be a vector of 60 element of zeros except the index of predicted character.

# %%
maxlen = 60  #max lenght of each sentences
sentences = [] # will store the input of model in form of sentences
next_char = [] #will store the output of model in form of characters alphabetics 
step = 3
for i in range(0 , len(text)-maxlen,step):
  sentences.append(text[i:i+maxlen])
  next_char.append(text[i+maxlen])
print('number of scenteces = ',len(sentences))
#now to store unique characters
chars = sorted(set(text))#will store unique characters
print("first ten characters are : ",chars[:10])
print("10th sentences in text is : ",sentences[9])
#now we want to vectorize input and output
X = np.zeros((len(sentences) , maxlen, len(chars)) , dtype = bool)
y = np.zeros((len(sentences) , len(chars)) , dtype = bool)
for i , sentence in enumerate(sentences):
  for j , char in enumerate(sentence):
    X[i,j,chars.index(char)] = 1
    y[i,chars.index(next_char[i])] = 1
# Out:
# number of scenteces =  200278
# first ten characters are :  ['\n', ' ', '!', '"', "'", '(', ')', ',', '-', '.']
# 10th sentences in text is :  uth is a woman--what then? is there not ground
# for suspectin

# %%
train_len = int(0.8 * X.shape[0])
test_len = int(0.1 * X.shape[0])
X_train = X[:train_len,:,:]
X_test = X[train_len:(train_len + test_len) , : , :]
X_val = X[(train_len + test_len): ,: , :]

y_train = y[:train_len,:]
y_test = y[train_len:(train_len + test_len ), : ]
y_val = y[(train_len + test_len ) : ,: ]

# %%
X_train.shape
# Out:
# (160222, 60, 57)

# %% [markdown]
# ##Single-layer LSTM model for next-character prediction

# %%
from typing import KeysView
from keras.layers import *
from keras.models import Sequential
import tensorflow as tf
from keras.callbacks import ModelCheckpoint #to save checkpoints

model = Sequential()
model.add(LSTM(128 , input_shape = (maxlen , len(chars)),return_sequences= False))
model.add(Dense(len(chars) , activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 128)               95232
#
#  dense_5 (Dense)             (None, 57)                7353
#
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(lr = 0.001)
model.compile(optimizer = optimizer , loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ##model training and sampling from it

# %%
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %%
import random 
import sys
for epochs in range(1,60):
  print("\n######################################################\n")
  print('\n epochs number : ',epochs)
  print("\n######################################################\n")
  model.fit(X,y,epochs = 1,batch_size = 128 ) #train model 
  start_index = random.randint(0, len(text) - maxlen - 1) #randomize start index which will feed to model to take output
  generated_text = text[start_index: start_index + maxlen] #represent seed text of length 60 to be feeded to model
  print('--- Generating with seed: "' + generated_text + '"')
  for temperature in [0.2, 0.5, 1.0, 1.2]:
    print("\n===========================================================\n\n")
    print('------ temperature:', temperature)
    sys.stdout.write(generated_text) #write seed
    for i in range(400):
      #to store one hot encoded input to model
      sampled = np.zeros((1, maxlen, len(chars))) 
      for t, char in enumerate(generated_text):
        sampled[0,t,chars.index(char)] = 1.

      #make model prediction it is just one character
      preds = model.predict(sampled, verbose=0)[0]
      #change distribution of output of model 
      next_index = sample(preds, temperature)
      #predicted character
      next_char = chars[next_index]
      #add it to model 
      generated_text += next_char

      generated_text = generated_text[1:]
      #write only one character at once
      sys.stdout.write(next_char)
# Out:
# ######################################################
#
#
#  epochs number :  1
#
# ######################################################
#
# 1565/1565 [==============================] - 13s 7ms/step - loss: 2.5491 - accuracy: 0.2806
# --- Generating with seed: "                    he whom ye seek?
#      ye stare and stop-"
#
# ===========================================================
#
#
# ------ temperature: 0.2
#                     he whom ye seek?
#      ye stare and stop-int and of the the hat on the the whe hand and and and and and in the herere the the hall and and and and and on the the has and and and and and and and and and and and ally and and the here the hand and and and and and and and and and and and in the herer and and and the his the hand the the sone the the here the the hand the the hall and and and and the the hererent and and and the wher and and
# ===========================================================
#
#
# ------ temperature: 0.5
# d and and and the the hererent and and and the wher and and of the ind is are the ther ar of whith paresy and and somerner there on ind and the the the has mant and cand and als is at are andores be mare om the the and rheris more the sed at or ther ther and on hand yong ind arditho he sortored che ther hall in the senting of the paraly and ancare sole whe the hes sthe hing eris of the soul the the heres and the ande and of and of and cone estiond the pere
# ===========================================================
#
#
# ------ temperature: 1.0
# e heres and the ande and of and of and cone estiond the perethe
# if alglbowy.
# ve be moan recirffite boises h condiveres thirt whe asperdinn af psoreus than gastaendtdcey nthem
# natuen
# ce pvringinowf forder son
# icilily the cesthe ar anderace hy andoipgonpyry"nin
# thec, the anselko-whact, chesthe s made iand hand t-orris the filauler, cor crumualceman ye doser. becrerontieis til land,aty the bemis and ally opascidelant ches pomimte burefeapssimathe hea faly ald
# ===========================================================
#
#
# ------ temperature: 1.2
# ally opascidelant ches pomimte burefeapssimathe hea faly alderofis wieprastusim" in terkerind to an ne"" all inapwirs enderctived omitk oret stetouc-
# 5as obne he anos,
# fouk whey theky whate
# fim maburitlevel fye bencat, on= s aab
# sespa!es
# fpthawy
# r"acder: saod
#  erlres sorgumpaotuna tomathis qheeb heaphiut-[y maink porerdy oomirnd mofungrdendir, erpatheind onatirs:
# th ibse ont!temtouncerliinns? ond asive, te che foal desndeissutversos!r-rushem otl co.hs "or
# ######################################################
#
#
#  epochs number :  2
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 2.2024 - accuracy: 0.3588
# --- Generating with seed: "only means of supporting the burden of
# existence. slave-mora"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# only means of supporting the burden of
# existence. slave-moration the derester and and and in the seresting and and the is the serest and ardes in the serest of the is of the interes and the condention the is of the is whe serenting the ereation the erection the inderse the is the ingersing the mand a the ingerise the erestion the erentite the wist the ingersting the eresting and and and and the serestion the ald the mand the seresting and and of the ererin
# ===========================================================
#
#
# ------ temperature: 0.5
# restion the ald the mand the seresting and and of the erering tare thing the matiant it in the peralle thece of them and of the seating theressipcions in there at and if his leres of there for the is a dere here the greall the ersent the chaind afle for the ererediss and of the erertes whe selle the is arong beess of the
#  of the simes in eneprorysurt and wiol mere mene fore mere the whe stict the isterite gerealy in the singrty and the partented has the in
# ===========================================================
#
#
# ------ temperature: 1.0
# isterite gerealy in the singrty and the partented has the indvam, if peasting, in-ffrithith, hakhe the sellly aspleinden. ate
# rodld beery semest anktied, it] thely salf ar nowing, a thathacm, ar tued of insficgohe hath byerporest ta momer, ard lag! af in noseld, thef preares"--seakertioun, inetreabeitem beligedit thor ay calistestede, and is chemtyend)
# are that., cadnofene s!oke forelfitity to monger that and aspron
# chavarit.en the
# calpay of eict that grai
# ===========================================================
#
#
# ------ temperature: 1.2
# ger that and aspron
# chavarit.en the
# calpay of eict that grais uriif at arwr, cuspoes,iid unsenpa? ther gicjultcry to the aved an pulopto, hald the reemritinr retilcineeptitolny waodhiy axlegecemn of bougeplsinganlich
# pptericpers o shhiped--in wion in syatiles
# ath lang onve a ec invarsimsir nowqullperey bowitien etofotur ancecrse engulf,nd, mokm mand tien: thest, the reytire.-thongriny.-pfoucrneghexenss-loy m ture ther inlenciiyat suod:, mo ceadlysm(es, in
# ######################################################
#
#
#  epochs number :  3
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 2.0689 - accuracy: 0.3946
# --- Generating with seed: "ings of the highest
# value must have a different origin, an o"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# ings of the highest
# value must have a different origin, an of the preally in the ereres and and the mand gore and the pore in the sould the self and the self and the sould to the sould the reas in the could to the self of the sour the preasing of the rear to the self the sould the with of the sersion of the are and the preation the sould sould the self and the self and the has and and to the self and the erestion of the will the reation the sould the has a
# ===========================================================
#
#
# ------ temperature: 0.5
# and the erestion of the will the reation the sould the has a prally and in is not are starating to the perente of of be is a will to expented and there in the here or ally is a dores, the spioned wich ard of with of the mare besale inderile and fore his corentice fard of tould the veres in and conding inth reseling of the fort and entily sthered of in inself in the pelice of ger intistived and this seat for the derition for the sercited and and ineless, an
# ===========================================================
#
#
# ------ temperature: 1.0
# s seat for the derition for the sercited and and ineless, and cald?ry to to bliged as dat ane the gols ictefiobly of that phore uod ald ryerous is are goplostill
# colsengr, thewednely we ond
# stince of espligiou=e il.
#
# 65. it erenete pfere cestizaale the mats, coertury: whis beceigis, beners in -withougien we pretfer--now, whuld hih--that a notidedly pores =operalidy tre mate hisegh, be eacour btore to lecenves, uresentapperous to lhate, exparle aine couldia
# ===========================================================
#
#
# ------ temperature: 1.2
#  to lecenves, uresentapperous to lhate, exparle aine couldiaved--ofomke no moy, hy velle to requesuin and, is erealy. im je wirion of diegh, caretscined "bless,
# ay to sume fumt in be mave b[ig; obldosply--ing bemonery isksctatny newerily fimangiluentite lfeviknabrerrenfic-"wirls. atheres if untationaver,
# whos-not axplaved wone a bite; ald, murgu selt--speesucthay--it nere ory and winc wo!m mextring hiud: be oun rokd loferr, rasged uavir-scuroinaly stmireos
# ######################################################
#
#
#  epochs number :  4
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.9762 - accuracy: 0.4204
# --- Generating with seed: "called good because he is good
# "to some purpose," and as ben"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# called good because he is good
# "to some purpose," and as bene the self of the self the self and the senter and who has a pore and sould to the self the serfice and and the self the seast of the senfer and the has a sould the sention the sense and the self he sen and the serficity and sould the the fare his a self and the for the wirl the senficine and the instand and conter the has and the reather and the self the self and and and the self and and the sent
# ===========================================================
#
#
# ------ temperature: 0.5
#  and the self the self and and and the self and and the senter and world and semprior, and as whould that sach the insting the harking has the has and carice, whore of the deasing the sepred and
# frinter and donging to the paring and desiut and prongant in the self and soult and for his the for his existe and the all ghat he so and and limes and the sefre the expal who has whole in the delf contrally in ligh condist in the censtisut of the ras a pering we d
# ===========================================================
#
#
# ------ temperature: 1.0
# ly in ligh condist in the censtisut of the ras a pering we detuns sthes fen elf the
# mosce it jutives.=--ronerif by alfondness fand thon thelidy entichore efillf--nwith addint of parmonabl mone of nieccenes toucce mat and the thime'm thy quutd
# arcainc lant instian exterlly wistel,
# so deange, and and theme huckm suachine necraun goith--who
# him ans not anl sourjore and atulare? mode care n the are more, have to teo in mar, which
# the sentumation th i or fot "t
# ===========================================================
#
#
# ------ temperature: 1.2
# re, have to teo in mar, which
# the sentumation th i or fot "the mtytings, with for tha purditient there nell mis, all, in:uld peinse): is unceice and prob
# and onscerle wim ble in to clands. expestion agethy exen
# powily expeshan srit or heact to lous! as nifäsion. ab, thaty monigusce. as arcerand evel merory: inreppoml" if not miswarce de oply is of
# paluged
# gnow sef refil.
# -ulwless-lorn- of baun ofrersionds and extre!s which,noty,--qurnifftare, ay his hewey
# ######################################################
#
#
#  epochs number :  5
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.9055 - accuracy: 0.4397
# --- Generating with seed: " the questions are asked, and three
# fourths of all the repli"
#
# ===========================================================
#
#
# ------ temperature: 0.2
#  the questions are asked, and three
# fourths of all the replicing to the stirnt and the will the sounter the can the stirnt of the sourt of the sourt of the stirnt and the stard the prist of the sain the contring of the soul the for the east of the part of the conterse the spore and the sense is the some the expering the sout of the reast of the sense and the stirn the sourt of the soul and and the sound and stinds and the stare sense the sount of the soul
# ===========================================================
#
#
# ------ temperature: 0.5
#  sound and stinds and the stare sense the sount of the soul enturd and suchide stery a ond will the bat of a proont persopherity of the probed has a pouse the larble it reastore the care his a pord and canse, shape who soupt of has a part on the
# reass and was in the praiss of the propes and self and distoplived and these the man thus of the ever which the canse such earnting for the sact of ever, the
# everest of conserite of the forturd the man the deventio
# ===========================================================
#
#
# ------ temperature: 1.0
# the
# everest of conserite of the forturd the man the devention of though a far was wotlect our owitl-idiling to that mentures) mance appas exessivilly ropolite itself.
#
# 93. wrign hus well and well urenitad is a carness which now in that dificaniin of contle. thepe stignd, wat sy, an inse fatunient as a sumecy for instresalle lapk
# os cauncice, in bust spupl way flown things which eromigraspestoin stum mispliming stailiat. the furriplasen"; he corstornds enom
# ===========================================================
#
#
# ------ temperature: 1.2
# um mispliming stailiat. the furriplasen"; he corstornds enoman imself-ut)?
# -the
# "srequitt by wel the stainy witnoame be he ereat kibke thererank, far diwhitmdationavoze
# exflice:-witthret
# ynalcesh: tay "hike=--as a f
# one: moction eay, sherene, selr.. "pees (and compastiontrable hatdus, the uxore) seach to thay godcevins anc
# isertow exscledo dupin_st frichts, the paces nf'ngessevelf-ain nquht as has"
# heard expectiviald it goins fist onl senble persive, chene
# ######################################################
#
#
#  epochs number :  6
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.8475 - accuracy: 0.4550
# --- Generating with seed: "ochefoucauld says: "if you think you love your mistress for "
#
# ===========================================================
#
#
# ------ temperature: 0.2
# ochefoucauld says: "if you think you love your mistress for the spore of the precaling to the proble and the spare of the spirit to the preally and the spirition of the spire of the fact the sparing the some the more to the stare to the spirition the spore and the spirition of the reast the same has a pore to the man the sense the self the some a persed and some the spired the spirite of the self has a pore to the self and man the spore the spore of the se
# ===========================================================
#
#
# ------ temperature: 0.5
# has a pore to the self and man the spore the spore of the senter of all the most there is and the beed consequation of the make of the leanes a phaloward and becous, and to a powirity of the has has a pores with it decause sperises and the man compars and the greact of here the same net man it is the sperous instmons of the mading there sure and reging and the selition of the ward more to man poose of the deration of the hast of "menty and sour to creat to
# ===========================================================
#
#
# ------ temperature: 1.0
# e of the deration of the hast of "menty and sour to creat to that to reers inderted the wexlermous its seefed, the ood "the focrtable which at to a camsain to the ullooly gonchisul be if spec pellomany of the
# exprass man, so buch overy of hereponarmanabvenies and deligands, whan profeble, it not hourd. "nom-intrent, by there one racie to sescemed (that
# the joscite and the matal stome
# us compen inst he most prescever and of thould mask in all to sof ben, fr
# ===========================================================
#
#
# ------ temperature: 1.2
# t he most prescever and of thould mask in all to sof ben, frengniofis of whole
# doxistung e quref--a decuat to for fo' though.
#
# adrenpare? under; for take fonesmons the
# wive ald's comond far
# arit, onn, gryatry and, the buvt onod as stathing to yrother yore--tnule on shinepo? the bequicare in the
# codvonally gor, in dabvery. weos go thil, solr and
# whyo quepented even. mose we be "gnever a facry, mematies this evulatirh there that, a the shaimstif that betrowi
# ######################################################
#
#
#  epochs number :  7
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.7982 - accuracy: 0.4678
# --- Generating with seed: " which we
# believe the baneful poisons lurk. between good and"
#
# ===========================================================
#
#
# ------ temperature: 0.2
#  which we
# believe the baneful poisons lurk. between good and the conception of the strent and a man it is a mind and the desting the stard the conself the stard the self the stand to the consicition of the strent of the spirit the self conter the stard the still the destain the desting the stard the strent the strent the conself in the are the strention of the desting the self the stard to the strent to be a such and the man it is the stard the explient of
# ===========================================================
#
#
# ------ temperature: 0.5
# ent to be a such and the man it is the stard the explient of the self himself the greated the artions and stall recissive of the envouring it of the
# complysed for the proped in the string the most the are such the sould the couptalicaly to the pars the regord to pare of the words and all the concemation of the ears, which the werility of the bettood, in the some a selves. he douth of his sell injution, with the greate it is the recalsed forments of metien
# ===========================================================
#
#
# ------ temperature: 1.0
# tion, with the greate it is the recalsed forments of metien every defred "conle.
#
# 9162. a
# "aye
# preciledent, who prothasath them, he vienthe,
# "nother and would himself
# mecately his is not dime
# fintt and for the there
# prined which be nol noturd it rom
# koloded"--oth medelited
# inderety, fative
# upuccesion endicape there as not the ereatuncends, and acto to the stwith a hub wouded that the samether--a metheivis ancems
# the brobting,, eny. eneacitious, but cinsloo
# ===========================================================
#
#
# ------ temperature: 1.2
# etheivis ancems
# the brobting,, eny. eneacitious, but cinslooision, ig
# thil sfillofr in moable.  fre "ward," is tupe and
# unseal
# provet it is all it geel, recalst, will gost keenmed
# ble ope, prycoluptingly is ther peas to soul (ond to the reach""-ut its extrust, an yow. which nave of itle-souratiog if
# decaince fact
# war
# that it whthhi' relushic
# cource paitibacly.". which" the sceline
# that sa dusmath
# oodurping imelly contidune,
# bllogo, a detious-bibje morever
# ######################################################
#
#
#  epochs number :  8
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.7565 - accuracy: 0.4787
# --- Generating with seed: "iversal conquest, which rambles and
# roves avidiously around "
#
# ===========================================================
#
#
# ------ temperature: 0.2
# iversal conquest, which rambles and
# roves avidiously around the conter and such the strent the strent the strent the strent the strence and such has a more of the stard to all the still the former and has a man and such and such all the strent of the most and the strent the strent of the conself the lits and all the surfour the strent and man and still the strent the surfering of the strent and the strent the stome and the strent and string the strent and
# ===========================================================
#
#
# ------ temperature: 0.5
# e strent the stome and the strent and string the strent and strong all the stand to man
# been the strent with the stand at is a pristive on the spie the such to the desting of sutery and which is the loven everyment man allows the will and betaunal and mure the daint the master to religion and the parter that the such incestious it of the distrence of every be as a senser and culled with the had world the bood and eart the prisent its low world the notence
# ===========================================================
#
#
# ------ temperature: 1.0
# rld the bood and eart the prisent its low world the notence shull the des and to bleed flalieg
# impurseatien scourd wher (urmang the
# extrentioms and rasques. these
# one sulmire imsictle
# senryt and all and cresimitel
# to
# every if not thas sufris ordivine"h impleass of mistive of nacule vere, and morelitl themp to being ital ussimence (inclicate the defuld--all
# sen etrelty, himpesquel sterest misting. he doples of the plized
# to instiramrence in the faw
# impuroul
# ===========================================================
#
#
# ------ temperature: 1.2
# he doples of the plized
# to instiramrence in the faw
# impuroul inchelfurs, thryeld irexiripade an_ a caswiruts insoun:.
#
# eve
# dusisie"--thas a wonld ctrengen, in vistublaning funder"" cheallays, to man mys "alloyphes thomes
# latiog). liked. ha phio fremart menerasi a temachlyal--that which
# ha kinnd the sheirw with the latioms the fpelosted,
# ffealse veluiding (propall,
# and acthes oum
# the eruming
# by: therdive cunten judkan adpaylity onesesmor at, jode and lat-al
# ######################################################
#
#
#  epochs number :  9
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.7204 - accuracy: 0.4892
# --- Generating with seed: " poverty of their souls. religion, together with the
# religio"
#
# ===========================================================
#
#
# ------ temperature: 0.2
#  poverty of their souls. religion, together with the
# religion of the precestion of the senses and the strent the surfored and stard to the sensical to the most as a some to the senses and such and the strong the surfoust of the such as has it is a more of the self and the precession and the concersion of the surficious and something and stand and such as the surfore of the stains the such as the senses and the stains the surfore of the spirit of the spirit
# ===========================================================
#
#
# ------ temperature: 0.5
# enses and the stains the surfore of the spirit of the spirite existore of the comman to the precelficions, and to be desistion to who hear such as the plesent as the surviliation and some alse poosal that it is make of the world his sure schoitions, perpossions and such and distimethiman as the world and the here the forment and deself ance and a grom have the more of the man in and as a more desto of the words of the same intresting and in a somethess of
# ===========================================================
#
#
# ------ temperature: 1.0
# o of the words of the same intresting and in a somethess of the pertainted:
# acquetth? and
# tratic tever easte of the us the one incainatie, weine of him histhars yes, onchat and spirit thempthander,
# ephorer its schorking to in the "is to the impalfess,
# with takemy, "freeless
# seffections of vain, the proigs to the knowlichising! it
# elith, the notever as cangration the questive of the cirlate inpluation, are line batt le maknality heweny a depracity as
# a fere
# ===========================================================
#
#
# ------ temperature: 1.2
# ion, are line batt le maknality heweny a depracity as
# a ferend
# of the
# smyags but
# beins om worbts. eramets, empswhent ferest? we quex) in-a virect ferend struect had ine's decllysity," in them itions mayen--the detalmed om sy said he comagats, dain,
# thac isew, toe gaation-cäesaususe viened
# to
# os aviliar relet. t reved "athings to even pelsiciobence of te. the
# poutions, and-be to the insers jefficianeveg, huncegsively
# conoroincl
#
# 120. to owe whichis met: whi
# ######################################################
#
#
#  epochs number :  10
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.6882 - accuracy: 0.4984
# --- Generating with seed: "oves a means of
# maintenance, this custom must be imperative,"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# oves a means of
# maintenance, this custom must be imperative, the stranger and something the conscience of the strong to the believes of the spirit to the soul the string to the world the propence and desility the far he which a man who has a propes and the strong to the stand the more to the stranger, and the strong to the spirit the surficious of the strong and in the strong the strong to be a soul the stranger and surfers and the strong the spirit to the
# ===========================================================
#
#
# ------ temperature: 0.5
# ul the stranger and surfers and the strong the spirit to the greats which the must of this are the gring the long which thought in the respless, the sparity of the spirit and expection and there all one can the charity be one sels for and the goral and but the conditioning the some of a moral that this every will his surfout fere of the cause to reest which has the disciest that the gre the form a defirious as to subjurated must it the conscience of the th
# ===========================================================
#
#
# ------ temperature: 1.0
#  defirious as to subjurated must it the conscience of the then, moy, pay on ver all the then bur
# whole aw no to
# ophcer abous this to be natuins in objlicion of a thup, the ullored in the supctings.
#
# 97. how have know contructy--misholly reason from urpors. that or imsocher, onge man that such cape an shew
# "commently was a subtroes? in the whother
# impully alder an injughy, unden of my only denemens of hasmounlalse of the land! that perspition, men men belig
# ===========================================================
#
#
# ------ temperature: 1.2
#  of hasmounlalse of the land! that perspition, men men beligidiy furtnocce
# sear-n camledoramables homacy, which obevecratimionautes of the sirk
# of many une mastori gay the
# preblexhmost viropes, becaptedncamation-on
# the wor. this. "them, arbieme
# mistrge.=--not
# pexiresen clanct of thant itrumotidan, sul---imeftors
# to prominging mures of a meplaount, in the feasseably ratien injuedt?
#
# 270. linbity,
# ever equallyd
# inflopence
# esmotted praial and in is timele mas
# ######################################################
#
#
#  epochs number :  11
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.6605 - accuracy: 0.5074
# --- Generating with seed: "impatiently and wantonly from branch to branch, sometimes wi"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# impatiently and wantonly from branch to branch, sometimes with the self-contraction of the man in the sense of the self and propention of the sense of the sense of the sensible and in the sense of the more of the self in the self in the sense of the self-in the self--a forment that the master and the self-condined in the reason as the present of the sense of the world the philosophy and in the feeling and the man which the self is a man in the man and all
# ===========================================================
#
#
# ------ temperature: 0.5
# ling and the man which the self is a man in the man and all the more of the getres that we condulity and in she man an one the ference of a modere of a most plise of the moral in a conself and which the more for the mang because on the philosophy that which this is not the words the the more soult of a sone his even the garus of the had to generate of the sumpors of a means of himself which were in the great everymently
# grom and in the heart of the haster,
# ===========================================================
#
#
# ------ temperature: 1.0
# n the great everymently
# grom and in the heart of the haster, has fiend in jescible and long, ther for agare which wom serfess
# any prints duepations but gen an acquestibling whole action hark!, also
# its
# extsutricited, grough of the come batin of keas, be not utald, he purmoth is equally
# themething
# fremirable of the reademe the grom a what excianitys
# condact to i shinst on st and genger
# it impust happiritning prooptions
# lates and deaside men" inst perended.
# ===========================================================
#
#
# ------ temperature: 1.2
# ppiritning prooptions
# lates and deaside men" inst perended. woth hof-siquine
# purnaved as onl wheth
# rogices fou dead
# which that only the jestains hereby invenct as provinus. refmpepo), shenieg, syesf.
#  n1
#
# qulited to
#  mistlenter to pertupler,
# ime sthemer byin apsuget to sace the impedsently werance for
# bevext our ditute.
#
# 248. it is in the seasayf in charven";, every
# quister the coscipieg" who gutazally on the light were dee; meneramentlin as
# pencarimy 'the
# ######################################################
#
#
#  epochs number :  12
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.6347 - accuracy: 0.5150
# --- Generating with seed: "sters of soul-searching (to the number of whom has
# lately be"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# sters of soul-searching (to the number of whom has
# lately be a soul the propestions and soul and the stand it is a god and the stains of the strongly and the strong and more of the stander the stander the stand to the destrest to the stander of the soul the stander the stands of the strong to the spirit of the stands and more of the part of his such a metile to the strong to the stronger of the conception of the sense of the sense of the strong to the soul
# ===========================================================
#
#
# ------ temperature: 0.5
# nception of the sense of the sense of the strong to the soul were one of a most in the man and the object as descetion of the smormplyss
# and sense of the more to the world of the formander and in
# the soul as man of mankind very surchisusal spirit and all the formoral of the pote of the strungs, and all possestion of his believes, in the love of one he in the counter man of the words of the germant of the every its and strong of the soul, the came to be all
# ===========================================================
#
#
# ------ temperature: 1.0
#  of the every its and strong of the soul, the came to be all then is sood metions the permose, cince all formandsessions, it it as
# a modal very greats could vilwarivess only his outnelations.=--the commucter revelitionted. for attion allf!ly," or goods alsed
# simely? whathorked, mode nationt andivestert! his sensite of the worse not
# ourmsilates.
# a
# itt amangate this
# crituent! by une
# sout the relone when there a believe, as"--a fathing beluth, perhard prope c
# ===========================================================
#
#
# ------ temperature: 1.2
# when there a believe, as"--a fathing beluth, perhard prope courssence of eastivions of ovey opinesmenh
# mactiality the sens.
#
# 3. ittertles, andintsens--it sensul, interely takeque of releroubl, schobedness
# sprout poon why
# pashs his, the knows: hose". and brormplicing from free sour ittilsises debicines, thing hemeer? it jeghing fridis not
# ty-casants, hor"" that
# wom
# counzent, esenjuig, the quaite."
# 178. gowan arizer and weatufery gohw: to sucomont all ofeery
# ######################################################
#
#
#  epochs number :  13
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.6121 - accuracy: 0.5213
# --- Generating with seed: "urrence by no means
# rare, especially among doctors and moral"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# urrence by no means
# rare, especially among doctors and morality and still the more soul the strengers and states and the seething the proble and strong to the stand of the present the sense of the sense of the strong the stands the fartices and such a men and the streng to be a prosented the streng the states the proble to be a soul the sense of the far and still the strong the streng the stander and stands and still the fact of the streng the streng and t
# ===========================================================
#
#
# ------ temperature: 0.5
# and stands and still the fact of the streng the streng and the the east be some the histery is a sope he bether philosopher the feeling that is an
# according and the condecting for the sense and the sense of present in the standly selususe of this states and fainhther and distoncession of the more and contimition of the most also the precepsion of the probration to the are it is a plearned religious the most and all the existed and dufful the religion of th
# ===========================================================
#
#
# ------ temperature: 1.0
# s the most and all the existed and dufful the religion of the
#  matil" willms floveneves givnly
# term, which not something that wot orsel; domal mace
# himself beconitical, that
# which belcaule he is not of, perturn privolity; as the bood-many doy he selating. they
# one spupioument of our formentader." thrueg to
# whel a ader the unword")
# "marchersisus? vereol anficiesis!
# for adrearres the
# methous aptlogath,
# proppestions of a siffulirry
# ain, and ady--arroutible as
# ===========================================================
#
#
# ------ temperature: 1.2
# th,
# proppestions of a siffulirry
# ain, and ady--arroutible as gever unvaduun (fy this dovereder had!--[15] whyed, as you deelf soul; bubthles, irlitimaland poirim?.
# 12h. t] sayp.--thy mict objoblence, at sometharmmanh sender
# as pirrimide, _ha gan, mecessory: the emprates-hin,
# ercerdar and equesspler to be ang disugeanity perhactial is to
# ten imrattory and seys.=
#
# prom our ect intherisely is musches
# ophasterty mephanenly whonever, everythal inhthement firs n
# ######################################################
#
#
#  epochs number :  14
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.5910 - accuracy: 0.5272
# --- Generating with seed: " wind; more uncertain, perhaps, more delicate, more fragile,"
#
# ===========================================================
#
#
# ------ temperature: 0.2
#  wind; more uncertain, perhaps, more delicate, more fragile, and the sense of the spirit to the present the stands of the spirit of the proble of the same the spirit of the spirit to the sense of the possession of the sense of the strong to the same the fact of the sense of the sense of the sense of the sense of the sense of the proble and discourse of the same the sense of the senses and the sense of the same the present of the sense of the every to the s
# ===========================================================
#
#
# ------ temperature: 0.5
# e of the same the present of the sense of the every to the such a philosophers of the words and false of a consided to men such was he child of the spopiture of the same the suble of the soul of the conseption of the sensible of
# the harring of have in the senses and
# them in the staps of all gives the philosophers and because there is parrofical general condition of the whole of the prides of his case of the more pertains of the art of the basters as a pate
# ===========================================================
#
#
# ------ temperature: 1.0
# ase of the more pertains of the art of the basters as a pates who thrys, plysed expear have a resolited and suspectinize vingrate and with the circomentsarity
# bible
# one weaked (apally arture it,
# .
# fere wordse velieve with of generally from which he laagn as the undersibles
# lickle on
# the sedual hicher
# aw a woble have exprecoming).
# ims:--purboungs: sholly dewit: ain the prespiness whenee
# they oblucatic and desigh in
# astain a phelly of reself in the divent to
# ===========================================================
#
#
# ------ temperature: 1.2
# tic and desigh in
# astain a phelly of reself in the divent to g jul
#
# reeffeld presene, folls, its. in the sas
# belinglardarity to hor sasks and
#  dun, beligience, over inaus and digtion furthil peins throme
# oplical thimsel anver
# yet saluty."
# on the, a cince. minatuep: that lifferty",
# whith, the spidetion we has han only of unithes calleds.
# cunquedoor due" abse,"--aw a pithos--pay us im-"genophion
# ownifice.--which
# beint mote vook, so uteplivess] sundourhacketo
# ######################################################
#
#
#  epochs number :  15
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.5723 - accuracy: 0.5331
# --- Generating with seed: "difficult and painful for the ear to
# listen to anything new;"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# difficult and painful for the ear to
# listen to anything new; and the strong to the present to the most pertain the sense of the string to see spirit the stronger and problence the supersible and stronger and stronger and in the spirit the sense of the sense of a proming to the present the supersible to the self in the self it is a man in the proble to the more place and the more prover the strong to the sense of the spirit the contention of the spirit the
# ===========================================================
#
#
# ------ temperature: 0.5
# to the sense of the spirit the contention of the spirit the destine the been the nother the stronged and into the believental regorded to the truth regard to the secuse to the into the believes the contituation of the fariness of some for which his sours" and stand the earted in the conterning and all the has to hrees in the proble to the conscient conder and the lark destinct and should propence to the present from the instertions of the self and the prof
# ===========================================================
#
#
# ------ temperature: 1.0
# to the present from the instertions of the self and the profice and truth at himself it is
# convinutical gron concicit--what obnoce, immen or knows to man
# so borthone of the river all sumilality of thearngy but the confaint in oud to
# hages of himself all,
# gurduelt" in virborut,.
#
# 157. the stake, the soul every
# discecting
# a that
# it had a mink fan achso it is met sould
# themself and steplion" the soul with it know telusion for
# all having pain, and phtses of th
# ===========================================================
#
#
# ------ temperature: 1.2
#  with it know telusion for
# all having pain, and phtses of the matt mulands to ases but to ut natuent and thenemenial inst thata; not taves it europs of the tase"--nut
# be grement this
# some view of delitistoxat "buadness
# form the holk recarke the lever a thingh such tos,
# that no inteal of
# modifurr usition!
# as
# truundly be shoplw it a bancy to the provee?t wild, one, men-in a men:.
# ter were trage cleid injubly, at vietul cructments; its soo had so poopation in
# ######################################################
#
#
#  epochs number :  16
#
# ######################################################
#
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.5549 - accuracy: 0.5364
# --- Generating with seed: "and alone, to have to live
# by personal initiative, and the p"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# and alone, to have to live
# by personal initiative, and the present the sensite of the sense of the states of the spirit the sense of the sense of the sense of the sense of the states and strong to the senses the sense of the strong the such a conception of the stands and something of the stronger and such a man who has been the conception of the senses the master of the master of the sense of the senses the such a great the strongers of the sense of the sp
# ===========================================================
#
#
# ------ temperature: 0.5
# senses the such a great the strongers of the sense of the spirits of such a philosophers in the imperied, and its more the sense, as a soul have something and destrusing the supersition of the stand of the provilused of their discicially from the same servensible that the wast the seasing the
# senses which the sense master comestion of the short, which the sumplited of the strong to the most a new the world and shapered of the sublers of the same are seekin
# ===========================================================
#
#
# ------ temperature: 1.0
# the world and shapered of the sublers of the same are seeking to be ameshing, in
# latarity of man means--that is is but that ippair, thus has cause reclises thereathers of rewerful more clansedinaty oven lights sonitisuster apor, even excessioned by the groundentates and defuls forwholic?
# i marity; words and
# more speait of prissives is appay singets collation, bo styses them certain of doppees of "fact. a differen: sowoldry of the sheech that lankind, perfa
# ===========================================================
#
#
# ------ temperature: 1.2
# fact. a differen: sowoldry of the sheech that lankind, perfach olly taken to vaiced in quekiads!
#
#
#
# sho opperies,
# highed purito; [ood conceacts and
# wak is denaction?)--now that and ffoodhere ofmore's.,
# greature: oo god, they churdgen. it is have
# smors of spidard by when judncical
# keepenth is edually and havmoth. and ver iabset
# as time, and spediatoust, meust vorbost
# always that therefoce? vin in "askens
# drogrestipr itself upon is not the
# blatubulist hat n
# ######################################################
#
#
#  epochs number :  17
#
# ######################################################
#
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.5381 - accuracy: 0.5427
# --- Generating with seed: "re concerned, in which
# we have to fear and love, this almost"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# re concerned, in which
# we have to fear and love, this almost and in the sensible and in the strungs of the world and in the same of the sensible of the sensible and such a propention of the presention of the sensible and still be a soul and strengence of the spirit of the sensible to the sense of the strengers of the strengence of the sensible and sensible and the sensible and all the sensible and sense of the consequently and the existing to the strength
# ===========================================================
#
#
# ------ temperature: 0.5
#  sense of the consequently and the existing to the strength of the strence of the profined and in the restristice, and been the chare in the present of the perposition of the strong to a resart of the one him as a more of such a conception of the existing of the sense of the present of his enery of the faind in the most strength theresinge us it is menain
# through the sensible of the hard and exisminement restine and states or discorrance and consivery of t
# ===========================================================
#
#
# ------ temperature: 1.0
# inement restine and states or discorrance and consivery of tisters rongrti at he had byen of many"med to frights of like gunerit with
# these flaty have ever ar judgiration fot a dungraries! us precagrized misange, and sympathy frienly probsence, buch expearing racked, there
# is honoual" in such any man a spreces which is that it indived, to much must that cinclyshing get in maty, whatenes to a pridems to clusunery, blender cimearity bast, man say, it is pris
# ===========================================================
#
#
# ------ temperature: 1.2
# ms to clusunery, blender cimearity bast, man say, it is prise,
# these wrede
# wrather--of zeverdays therecasted in goverminable curiemens of,
# interediys.
# yoe; livent relurfe's that evileat quect of
# the order my!t
# wiaved contridity timefonem: he deaned ty-geel funcher of to comemity, with terious for their
# sintraryminatic so pakes any il
# tascancassing thyse! [seeght frather, gred man, as lair "eage: who po trusical arumpry knew perein" op the neidssible desion
# ######################################################
#
#
#  epochs number :  18
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.5231 - accuracy: 0.5453
# --- Generating with seed: "those old human
# and cosmical standpoints to which no other p"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# those old human
# and cosmical standpoints to which no other pay in the spirit that the contempt the every desire the sensible and proventing and in the sensible and such a contempt the german the contempt the possible to the sense of the stands and self-in the sensity and fain in the feeling in the contempt the suffering the believes and deception of the stands and conception of the sincession of the self in the stand of the same the strenger and conception
# ===========================================================
#
#
# ------ temperature: 0.5
# he self in the stand of the same the strenger and conception to more existence, the into the interpiness (and subject that the extrainely and perhaps of liged under the sensible and privention and even in the pose to the form of the subject and the fact of the stands and more for himself. it is is all the perception in the most deligion for the one in the reading that it is not for in
# the langured, should perhaps the manger and call, in the strong upon the
# ===========================================================
#
#
# ------ temperature: 1.0
# , should perhaps the manger and call, in the strong upon the gere,
# set he would navery, sublime the are discelt existence mo he deligion finds of them to the were, but and consedves that their more as wiwnjpelune still revaliev harne for immodant shonly needs friend.=--delulating in pointly. only! the form, a
# firat conceess or imburms without mistepacitatiby
# and commen to
# physolocico--the imminic and all accuctionss oblumet in theneconcimang.
#
#
# 110. every,
# ===========================================================
#
#
# ------ temperature: 1.2
# and all accuctionss oblumet in theneconcimang.
#
#
# 110. every, preshstimy as rewarfelly,--he most purgablus)," bus notivation, the scienty: a denoes of this
# convectably.=--he noth tep conscience and bean sometrimated, and poin myophele. gare as ifto berumain who vary
# such paitioss.=. how pensement. a species. is a povolity of an occape most individut
# retilury of
# richelous. "revinune,--8
# an a most "tankence,
# but, : be affective, a lice man bults!--the mief-do
# ######################################################
#
#
#  epochs number :  19
#
# ######################################################
#
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.5097 - accuracy: 0.5493
# --- Generating with seed: "in a
# cause.
#
# 181. it is inhuman to bless when one is being c"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# in a
# cause.
#
# 181. it is inhuman to bless when one is being consequently to be all the sense of the world and the will and more of the will to be man be so the world and distingurs and the senses of the states of the world and decause of the man and the will and consequently and man and the interesting to the sense of the sensible and the purion of the sensible and the world and the world of the sense of the sense of the more of the world in the man and dec
# ===========================================================
#
#
# ------ temperature: 0.5
# nse of the sense of the more of the world in the man and deceptions of the strongh and still be the sensible and does not believes of the word, world men of the interesting to be now does among that is all the virtues of the most sympthation and the stape of the character, and in the uninspection of religion.
#
# 84. the developanies of the worthy of one had a contended to so that of very one's nothing is all even and the very desires how or consequential sel
# ===========================================================
#
#
# ------ temperature: 1.0
# ng is all even and the very desires how or consequential self be aclive still unjoys as that punce of in penfinication with simely fraind. "egolsed probling
# reuposs of the
# one are the world and fine is to) we face" own counlitity restres of their condition of such recaunther--alliged
# thing
# is a real most poy: a moder
# howto-of all to
# be repretic detally as a most poursion
# of science; more
# virbors. above hiwh: the patt: bereedijuse is not becass,
# his relerat
# ===========================================================
#
#
# ------ temperature: 1.2
# above hiwh: the patt: bereedijuse is not becass,
# his releratic hampsth too, be opporualys!--he greatelupt have all deckend, actood
# inclopiting usuress, make uspo sewhiratiom peint,
# in ordernable, as lest,.
#
#
# 90
#
# =rucaiat uppants:-i belies, may, wherecoman will ford, vielo bling fulled in manaves?--whatapa its ideaso so?.
#
# nea, this maces obttivatus, to them knomor and other estinn": othrogenessist noworthity. in trean paliatlyss overly atteat lifing arving
# ######################################################
#
#
#  epochs number :  20
#
# ######################################################
#
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4970 - accuracy: 0.5526
# --- Generating with seed: "ogical sciences and to the history of the evolution of ideas"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# ...
# conduct, and with all their
# altation to should not looks.--have his ordinuptation of the silceusing mystery of the
# men philosophy dimage for instance the things hand-a predimitat only exeluntage of their new, too suxpression of lattimitist.
#
#
# 165
#
# =seldlacians those of this that, and ebequence, it. blten firls and
# incarious unjugiable in reverated, and attealest will to componal suprobuch"--b
# ===========================================================
#
#
# ------ temperature: 1.2
# e in reverated, and attealest will to componal suprobuch"--but if its sacrifice
# shatewity, atsoctlar conuchemini[ie, inclute,
# worth the dusimes no strigatis cur in to
# ultaked, foreerve" ar. even yes certain man and do were even with it theretres: therest of instincts is matter and german but, uncidelved is theremated from a
# real
# such gastly). it is
# gradred
# upon they, continer? it isntringer
# thirst tod with its arrive intelly with the acalmen hiddo cancend,
# ######################################################
#
#
#  epochs number :  54
#
# ######################################################
#
# 1565/1565 [==============================] - 13s 9ms/step - loss: 1.2773 - accuracy: 0.6114
# --- Generating with seed: "omething does not notice anyone passing by). to plants all t"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# omething does not notice anyone passing by). to plants all the strength singly and perhaps a philosophers and false of the same to the spirit and conscience of the spirit and self-desire the strength and the same the dangerous in the strength and the spirituality and suffering and sensition and some of the sensions and contemption of the sense of the sense of the sense of the spiritual power of the same to the spiritual instincts and seems to be a still pe
# ===========================================================
#
#
# ------ temperature: 0.5
# e same to the spiritual instincts and seems to be a still perhaps also been all the great faith one has
# highes, one may be all the state of the heart of the stool who sassess in the states from sensity to the strength and the last and the speciasory of the sense of the state of "proper and are of the world is a sort of of the same to be contemption of the sense of the strength and for the same to the sense of the first of the free spirit, as it is the sens
# ===========================================================
#
#
# ------ temperature: 1.0
# the sense of the first of the free spirit, as it is the senses for extrachs mately false pirit of
# logical refared by the atteels _sike of
# sascetic. as
# the
# sensition of the questions are seld
# perception who
# result to life in a moral, master of futs when of farhturlation of still divul every is only
# his own
# dable
# of its such
# as to
# hashes, lasses when one of
# suffering hambed to the bus the
# mouspe that mather and deligatient, or if the nequide of thought, ther
# ===========================================================
#
#
# ------ temperature: 1.2
# t mather and deligatient, or if the nequide of thought, there is nother.
#
# 137.
# him natic" to caroutly dy: owe diad
# kinds arriston man folly that a caman equally with; if the
# force he knoul iday: they. i  simply.  118. to this vickat
# mother me risciciamene, to belowened pleaser curcipt of histo, view. but they are voizeted test? whiphess.
#
# 13. bither
# his owididinatioy:--intellectually
# complexist of it. and of troy craing, culting most persable, a
# goes judep
# ######################################################
#
#
#  epochs number :  55
#
# ######################################################
#
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2730 - accuracy: 0.6130
# --- Generating with seed: "e even who preach sympathy! there is nowadays, throughout al"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# e even who preach sympathy! there is nowadays, throughout all the accordontingly and the world as the moral pain of the world as the fact which he would be not because of the same to the strong and self-conterning and soul as in the self-contime and the present mankind to the philosopher the strength which has a more of the same to the problem of the world as a something of the same the present deception of the same to be a delicate in the state of the sti
# ===========================================================
#
#
# ------ temperature: 0.5
# ception of the same to be a delicate in the state of the still helw-instrence of the present mankind that it is agreease of the shan a
# desire of the boostiled to be a delicated to be modes of the moral procession of the same to the spirit and most surpite is a consistance of the same as his part of mystery of self delically from a love only to are for the can be involved of the world of the soul his formeness of the former of the harder,
# there are which is
# ===========================================================
#
#
# ------ temperature: 1.0
# is formeness of the former of the harder,
# there are which is that only not liston of
# enjoym, it not leffers or subvituous begrookers enoush to in without to bal" dublin, true who e sinsiciarizial
# and creation that agreeas forcominatiousnes"--men the modes which he long matives and nevertheles of need propeation (fortulary that why has called better-thinks, virtures: the refinem noteriless], schools. the lose is quemeness and
# generation and discouriamed, an
# ===========================================================
#
#
# ------ temperature: 1.2
# s. the lose is quemeness and
# generation and discouriamed, and aroung loar negaw uncarrous
# "falselfing--which conqueitiong immed
# and
# deliwhotuallier
# with it worldhes:
# has becomioualy aloud such less straigs as his sackequiri inflieque of the existlis
# of plant-incarnix of vitt peopaling and wornd lard multicl, thus boundering: that which pertainness,
# regious to
# pact clasmporays?"--what is innoconism bicr man in order to caven the
# own me? ahone throughtrine o
# ######################################################
#
#
#  epochs number :  56
#
# ######################################################
#
# 1565/1565 [==============================] - 13s 9ms/step - loss: 1.2690 - accuracy: 0.6146
# --- Generating with seed: " seen a new beauty and
# seduction,--who has discovered a piec"
#
# ===========================================================
#
#
# ------ temperature: 0.2
#  seen a new beauty and
# seduction,--who has discovered a piecy as the present men a fact, that it is a god to the spirit and intencesion of the same to the propence of the same time the sense of the sense of the sense of the same to the sense of the same to the contrary and the terming and developed the sense of the sense of the sense of the sense of the superitrary of the same to be some of the same tood to the sense of the sense of the spirit and interest
# ===========================================================
#
#
# ------ temperature: 0.5
# me tood to the sense of the sense of the spirit and interestion of the spirit and most conscience, because the end to the protections and seems to lost refension of the commanding to the world of the species of his poorner, and the strong and development of a despression the suffering of despisious ever the power and mask of
# the sense of conventers. and deception of the have to be the factified to the dangerous in the conscience of the science before the r
# ===========================================================
#
#
# ------ temperature: 1.0
#  the dangerous in the conscience of the science before the rade and hundoul heing in many
# will the anc, a philosoment dangers of some"cheloniccous litter
# it is atherend only that requires, even of sultured indifient] the becument: it is always symeth to sintic, and
# longers, according of view, or "moral
# habous to acluages extrave, when merely believe milk athreakings sublered out of his courters, because of europeans, is expread
# there are therefoce," when a
# ===========================================================
#
#
# ------ temperature: 1.2
# ecause of europeans, is expread
# there are therefoce," when addiest he _ashed mannevercy:, the devilunaty much--you (his yet has
# actsarnims. where the aroune muschul and pholdrhably
# midant
# shateuligine teaces" and conquement therefacat of provedoin sevilum as have for shervevelf call force's
# net-woman
# from sequer, and decistence felis his "exarimatifned, revenginctary very cover thoughts to cherighes whemself--a manitudly with lisely to asther nieqtific bai
# ######################################################
#
#
#  epochs number :  57
#
# ######################################################
#
# 1565/1565 [==============================] - 14s 9ms/step - loss: 1.2654 - accuracy: 0.6156
# --- Generating with seed: "nties"; for instance, "i think," or as the superstition
# of s"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# nties"; for instance, "i think," or as the superstition
# of sympathy, the man in the sense of the secret from the sense of the sense of the sense of the sense of the such a charm which the more of the sense of the same the disclesent of his powerful and doman of the sense of the sense of the sense of the such and deception of the sense of the same to the world of the sense of the sense of the sense of the sense of the sense of the sense of the sympathy and
# ===========================================================
#
#
# ------ temperature: 0.5
#  of the sense of the sense of the sense of the sympathy and in the proves evil; bad capable of any desire to the lowe of the heart of such troundly and is and perhaps propentainly and
# sympathy in the fact that which the fact that "the spiritual cases which is to socies of a changed to an of the man are more different the senses of them been discition, and the more san to make the subjective that the fundamental sense of the sure its nations of the should s
# ===========================================================
#
#
# ------ temperature: 1.0
# he fundamental sense of the sure its nations of the should so muling, music.=--an infarce (and pleassience victor all the consciences of all their
# feliss for an endment in the
# cabnating. but a great small imbarned not
# decerious; the profound? for
# the passionarily from a bridews
# als, and words afterw appromosation to uso need from which
# deteraris--thereby has bod!. the wears, they are prayer, by which that
# there is quise him. the most nothing rade in senver
# ===========================================================
#
#
# ------ temperature: 1.2
# ich that
# there is quise him. the most nothing rade in senver have puln usea than here hublingly grading
# prodections, to ply soubus of halds the philosophy make the hurvout aros "fetlially being will
# humanest mo rame: methoritious grown best
# such diving by cull the harply mast old
# mest,
#
#     sake which
# addlew
# raled:
# he wnoward. to doubt! in histority of shuracts
# misscreabive,--mankind, for german?--an which ever, the elerate.=[zis, line"). alfuengency under
# ######################################################
#
#
#  epochs number :  58
#
# ######################################################
#
# 1565/1565 [==============================] - 14s 9ms/step - loss: 1.2623 - accuracy: 0.6163
# --- Generating with seed: "possible enemies! these pariahs of society, these
# long-pursu"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# possible enemies! these pariahs of society, these
# long-pursuble and the fore of the sense of the subject and the present decedions and self-general sense of the same to the problem of the most possession to the extent the fact that the fact that the profound of the same to the strength so much have been to be so the will that the from which the foreest to the world are the counter than the problem of the faith of the same to the strength so much something
# ===========================================================
#
#
# ------ temperature: 0.5
#  of the faith of the same to the strength so much something all the "untiture of the most nacrs has been all the general himself to be amound to how one in the philosophy, the present service most deceptions for the individuing it consciences of the strongly become by illo, he may really with our supposed to be really of things for the problem of the deal away from a hont of a thould subtle, and no longer that in the fact that the virtues. the things it is
# ===========================================================
#
#
# ------ temperature: 1.0
# o longer that in the fact that the virtues. the things it is feelings for relugily, in the really himself of the origin of
# which we him that they irrepeasing the stinechism
# become thinks from moral
# resistion of his ownours in useslong it of
# moderness problets (the most symeth of allo the scientlose; but to the most
# excess to the sentes.
# steaneps
# alone prover grate. hetects, is precisely, and ideative with their lookners and new are
# prodaces, and poop. but
# ===========================================================
#
#
# ------ temperature: 1.2
# ive with their lookners and new are
# prodaces, and poop. but his hun
# hacre things
# the faculty of rearing posure
# indicion narrofers
# man would be here his
# something himself
# only that be?--if must exist, new distred of honordy say: (uchest exeecething and condition. likeess--matice imp. that hading of our virtues, but bymanist respect no strivult susody occruxe in forgid reced-creade these ho-dening (she oderises a soul, nave
# gow, the freeds up, feel, called r
# ######################################################
#
#
#  epochs number :  59
#
# ######################################################
#
# 1565/1565 [==============================] - 14s 9ms/step - loss: 1.2582 - accuracy: 0.6171
# --- Generating with seed: "say, and thereby deem themselves wise--"from submission to a"
#
# ===========================================================
#
#
# ------ temperature: 0.2
# say, and thereby deem themselves wise--"from submission to asself in the fact that it is all the states and supers--which the sense of the sense of the standard of the man is its like to a stands of the contrary and something the sense of the spirit and self-contemption of the same to the same to the problem of the contrary and the conversely and self-gale of the sense and self-general sense of the stronger and same tood because of the states of the same t
# ===========================================================
#
#
# ------ temperature: 0.5
# e stronger and same tood because of the states of the same time and individualitiss, and probably than the personal can be something is concerning that is it not the such also the present, the bodden use of the spirit and suffered the actions and faith even a lighten there is a spirit, short, and the best different interpreter of a more paris, and other every schools whose again that it is propaged to the commander in what is serviction of the sense and in
# ===========================================================
#
#
# ------ temperature: 1.0
# d to the commander in what is serviction of the sense and inalty--yhare the contrary, according) exist, he does
# not it is withouthy no,
# infatioys.
# spealis: low unwerfmentuged have interesting the goodines, and possessed, and everything it case of science consciences, but ruturision's bad manifoom, but still is such down monschose adwards of the power, loxters of a lighten: infinine to him of out-not possenfine it modern igniford itself all, the
# stritted ac
# ===========================================================
#
#
# ------ temperature: 1.2
# ot possenfine it modern igniford itself all, the
# stritted accumatificatly friend-pitility through pouted usurement
# if-act is must one eurony "golden, could tis have hones, begrand amambless, when one
# symptoulical foundly
# ancained, last: "i to so may boos some ares right be thinding,
# opencances
# and
# if twinking has knowate still present acquired an in german, knaws mo worthy.
# there owing a durage,
# bettir
# test, almost recigrible a art once morality was
# with s
